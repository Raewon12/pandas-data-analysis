# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\python_src\rawon.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python_src\rawon.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\python_src\rawon.venv\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\python_src\rawon.venv\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python_src\rawon.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python_src\rawon.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python_src\rawon.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\python_src\rawon.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 라이브러리 불러오기
import pandas as pd
import seaborn as sns

# # titanic 데이터셋 로딩
titanic = sns.load_dataset('titanic').rename(columns={'sex':'gender'})

# # 행 인덱스 0~9 범위에서 age, fare 2개 열을 선택하여 데이터프레임 만들기
# df = titanic.loc[0:9, ['age','fare']]

# # 데이터프레임 출력
titanic.head(3)
titanic_simple = titanic.drop(cloumns = ['alive','class','who','embark_town'])
titanic_simple.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 13
#       8 # # 행 인덱스 0~9 범위에서 age, fare 2개 열을 선택하여 데이터프레임 만들기
#       9 # df = titanic.loc[0:9, ['age','fare']]
#      10
#      11 # # 데이터프레임 출력
#      12 titanic.head(3)
# ---> 13 titanic_simple = titanic.drop(cloumns = ['alive','class','who','embark_town'])
#      14 titanic_simple.head(3)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'cloumns'. Did you mean 'columns'?

# %%
# 조건식 적용 (20세 미만: age < 20)
titanic['age'] < 20
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
# 불린 인덱싱 (20세 미만의 조건을 충족하는 행을 필터링)
titanic_under20 = titanic[titanic['age'] < 20]
#생존자
titanic_under20[titanic_under20['survived'] == 1 ]
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 22          1       3  female  15.0      0      0   8.0292        Q   Third
# 39          1       3  female  14.0      1      0  11.2417        C   Third
# 43          1       2  female   3.0      1      2  41.5792        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 855         1       3  female  18.0      0      1   9.3500        S   Third
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 22   child       False  NaN   Queenstown   yes   True
# 39   child       False  NaN    Cherbourg   yes  False
# 43   child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 853  woman       False    D  Southampton   yes  False
# 855  woman       False  NaN  Southampton   yes  False
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 887  woman       False    B  Southampton   yes   True
#
# [79 rows x 15 columns]

# %%
# 불린 인덱싱 (loc 인덱서 활용)
df.loc[df['age'] < 20]
# Out:
#     age     fare
# 7   2.0  21.0750
# 9  14.0  30.0708

# %%
# 불린 인덱싱 (NOT 논리연산)
df.loc[~(df['age'] < 20)]
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 8  27.0  11.1333

# %%
# 나이가 10대(10~19세)인 승객 (AND 논리연산)
mask1 = (titanic.age >= 10) & (titanic.age < 20)
df_teenage = titanic[mask1]
df_teenage.head()
# Out:
#     survived  pclass  gender   age  sibsp  parch      fare embarked   class  \
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 38         0       3  female  18.0      2      0   18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 9   child       False  NaN    Cherbourg   yes  False
# 14  child       False  NaN  Southampton    no   True
# 22  child       False  NaN   Queenstown   yes   True
# 27    man        True    C  Southampton    no  False
# 38  woman       False  NaN  Southampton    no  False

# %%
# 나이가 10세 미만(0~9세)이고 여성인 승객 (AND 논리연산, loc 인덱서)
mask2 = (titanic.age < 10) & (titanic.sex == 'female')
df_female_under10 = titanic.loc[mask2]
df_female_under10.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 나이가 10세 미만(0~9세)이고 여성인 승객 (AND 논리연산, loc 인덱서)
# ----> 2 mask2 = (titanic.age < 10) & (titanic.sex == 'female')
#       3 df_female_under10 = titanic.loc[mask2]
#       4 df_female_under10.head()
#
# File c:\PYTHON_SRC\rawon.venv\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sex'

# %%
# 나이가 10세 미만(0~9세) 또는 60세 이상인 승객 (OR 논리연산)
# age, sex, alone 열만 선택 (loc 인덱서, fancy indexing)
mask3 = (titanic.age < 10) | (titanic.age >= 60)
df_under10_morethan60 = titanic.loc[mask3, ['age', 'sex', 'alone']]
df_under10_morethan60.head()
# Out:
#      age     sex  alone
# 7    2.0    male  False
# 10   4.0  female  False
# 16   2.0    male  False
# 24   8.0  female  False
# 33  66.0    male   True

# %%
# 불린 시리즈를 새로운 열로 추가
titanic['age_under_20'] = titanic['age'] < 20
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_under_20
# 0    man        True  NaN  Southampton    no  False         False
# 1  woman       False    C    Cherbourg   yes  False         False
# 2  woman       False  NaN  Southampton   yes   True         False
# 3  woman       False    C  Southampton   yes  False         False
# 4    man        True  NaN  Southampton    no   True         False

# %%
titanic_under20 =  titanic[titanic['age']<20]
titanic_under20 = titanic_under20.rename(columns={'sex':'gender'})
titanic_under20[titanic_under20['gender'] == 'female'].head(3)
# Out:
#     survived  pclass  gender   age  sibsp  parch     fare embarked   class  \
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
#
#       who  adult_male deck  embark_town alive  alone  age_under_20
# 9   child       False  NaN    Cherbourg   yes  False          True
# 10  child       False    G  Southampton   yes  False          True
# 14  child       False  NaN  Southampton    no   True          True

# %%
titanic.loc[~(titanic['age']<20)].head(9)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 5          0       3    male   NaN      0      0   8.4583        Q  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone  age_under_20
# 0     man        True  NaN  Southampton    no  False         False
# 1   woman       False    C    Cherbourg   yes  False         False
# 2   woman       False  NaN  Southampton   yes   True         False
# 3   woman       False    C  Southampton   yes  False         False
# 4     man        True  NaN  Southampton    no   True         False
# 5     man        True  NaN   Queenstown    no   True         False
# 6     man        True    E  Southampton    no   True         False
# 8   woman       False  NaN  Southampton   yes  False         False
# 11  woman       False    C  Southampton   yes   True         False

# %%
#1등석, 2등석 pclass
#선실별 승객수 len(데이터 프레임)
# sns.barplot(data = titanic, x='pclass', y='survived' , hue='gender')

# print(len(titanic[titanic['pclass'] == 1 ]))

# print(len(titanic[titanic['pclass'] == 2 ]))

# print(len(titanic[titanic['pclass'] == 3 ]))

titanic['pclass'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64>

# %%
pd.Series([
    len(titanic[titanic['pclass'] == 1]),
    len(titanic[titanic['pclass'] == 2]),
    len(titanic[titanic['pclass'] == 3])
],index=['1등석','2등석','3등석']
)
# Out:
# 1등석    216
# 2등석    184
# 3등석    491
# dtype: int64
